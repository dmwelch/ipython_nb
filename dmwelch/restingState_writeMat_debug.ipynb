# %%
# !ls /paulsen/Experiments/rsFMRI/rs-fMRI-pilot/workflow_jvaidya_Feb2013/_session_id_14570/writeMatFile1/
# Out:
# _0xca25ca176fe6744dc69af25ff418bf90.json _report                                  errts_Decon+orig_dtroiStat_raw.mat
# _inputs.pklz                             errts_Decon+orig_dtroiStat_corr.mat      result_writeMatFile1.pklz
# _node.pklz                               errts_Decon+orig_dtroiStat_labels.mat

# %%
import scipy.io as io
import numpy as np

raw = io.loadmat('/paulsen/Experiments/rsFMRI/rs-fMRI-pilot/workflow_jvaidya_Feb2013/_session_id_14570/writeMatFile1/errts_Decon+orig_dtroiStat_raw.mat')
data = raw['data']
tdata = np.transpose(data)
print data, "\n\n==========\n\n", tdata
assert np.all(np.corrcoef(data, rowvar=0) == np.corrcoef(tdata))
# Out:
# [[ -3.37481000e-01   3.58179000e-01  -8.57068000e-01 ...,  -2.56940700e+00
#     1.78603000e+00   9.13898000e-01]
#  [ -2.20521000e-01   2.35866000e-01  -7.65674000e-01 ...,  -1.98650800e+00
#     1.66812400e+00   1.03640700e+00]
#  [  3.10443000e-01  -6.43788000e-01  -1.64462100e+00 ...,   8.54801000e-01
#    -2.78452000e-01   1.15349200e+00]
#  ...,
#  [  1.40000000e-05  -7.69710000e-01  -9.15743000e-01 ...,   3.58426900e+00
#     2.87829800e+00   1.84401400e+00]
#  [  5.86750000e-01  -7.76695000e-01  -9.01853000e-01 ...,   4.59589500e+00
#     1.92860000e-02   1.10408900e+00]
#  [  1.29235200e+00   1.79596000e-01   7.59284000e-01 ...,   5.17886000e-01
#     1.86413000e-01   1.55232100e+00]]
#
# ...
#
# [[ -3.37481000e-01  -2.20521000e-01   3.10443000e-01 ...,   1.40000000e-05
#     5.86750000e-01   1.29235200e+00]
#  [  3.58179000e-01   2.35866000e-01  -6.43788000e-01 ...,  -7.69710000e-01
#    -7.76695000e-01   1.79596000e-01]
# ...

# %%
count = 0
while open('/paulsen/Experiments/rsFMRI/rs-fMRI-pilot/workflow_jvaidya_Feb2013/_session_id_14570/afni3Ddetrend/errts_Decon+orig_dt.nii', 'r')
# Out:
# 7=File    Sub-brick       NZMed_2         NZMed_4         NZMed_5         NZMed_7         NZMed_8         NZMed_10        NZMed_11        NZMed_12
#        NZMed_13        NZMed_14        NZMed_15        NZMed_16        NZMed_17        NZMed_18        NZMed_24        NZMed_26        NZMed_28
#        NZMed_30        NZMed_31        NZMed_41        NZMed_43        NZMed_44        NZMed_46        NZMed_47        NZMed_49        NZMed_50
#        NZMed_51        NZMed_52        NZMed_53        NZMed_54        NZMed_58        NZMed_60        NZMed_62        NZMed_63        NZMed_72
#        NZMed_77        NZMed_85        NZMed_251       NZMed_252       NZMed_253       NZMed_254       NZMed_255       NZMed_1000      NZMed_1001
# ...
